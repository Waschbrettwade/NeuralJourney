# %%
from IPython.display import display
from PIL import Image
img_PIL = Image.open(r'RNN6.png')
display(img_PIL)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1364x702 at 0x221EE0D7940>
